# %%
top_posts = df.sort_values(by='engagement_rate', ascending=False).head(10)
top_posts
top_posts['platform'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 top_posts = df.sort_values(by='engagement_rate', ascending=False).head(10)
#       2 top_posts
#       3 top_posts['platform'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['length_category'] = pd.cut(df['post_length'], bins=3,
                               labels=['Short','Medium','Long'])

df.groupby('length_category')['engagement_rate'].mean().plot(kind='bar')
plt.ylim(0.0650,0.0675)

plt.title("Engagement Rate by Post Length Category")
plt.ylabel("Average Engagement Rate")
plt.savefig("engagement vs post length")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_21892\929938288.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('length_category')['engagement_rate'].mean().plot(kind='bar')

# %%
df['engagement_rate'].describe()
# Out:
# count    10000.000000
# mean         0.066696
# std          0.031598
# min          0.011227
# 25%          0.039637
# 50%          0.066719
# 75%          0.093694
# max          0.132124
# Name: engagement_rate, dtype: float64

# %%
plt.figure()
plt.hist(df['engagement_rate'], bins=30)
plt.title("Distribution of Engagement Rate")
plt.xlabel("Engagement Rate")
plt.ylabel("Frequency")
plt.savefig("distribution of engagement rate")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure()
corr = df[['likes', 'comments', 'shares', 'views', 'engagement_rate']].corr()

sns.heatmap(corr, annot=True)

plt.title("Correlation Heatmap")
plt.savefig("correlation heatmap")
plt.show()

# %%
df[['likes', 'comments', 'shares', 'views', 'engagement_rate']].corr()
# Out:
#                     likes  comments    shares     views  engagement_rate
# likes            1.000000  0.877651  0.825058  0.740044         0.584816
# comments         0.877651  1.000000  0.720223  0.648297         0.546161
# shares           0.825058  0.720223  1.000000  0.608048         0.516389
# views            0.740044  0.648297  0.608048  1.000000         0.014413
# engagement_rate  0.584816  0.546161  0.516389  0.014413         1.000000

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(post_avg.index,post_avg.values,width=0.2)
plt.ylim(0.0650,0.0675)
plt.title("Average Engagement Rate by Post Type")
plt.xlabel("Post Type")
plt.ylabel("Average Engagement Rate")
plt.xticks(rotation=45)
plt.savefig("engagement rate vs post type")
plt.show()

# %%
post_avg = df.groupby('post_type')['engagement_rate'].mean()
print(post_avg)

# Highest
highest_value = post_avg.max()
highest_content = post_avg.idxmax()

print("Highest content type:", highest_content)
print("Engagement rate:", highest_value)

# Lowest
lowest_value = post_avg.min()
lowest_content = post_avg.idxmin()

print("Lowest content type:", lowest_content)
print("Engagement rate:", lowest_value)

# Percentage Difference
percent_diff = (highest_value - lowest_value) / lowest_value * 100
print("Percent difference:", percent_diff)
# Out:
# post_type
# Image    0.067147
# Text     0.066026
# Video    0.066903
# Name: engagement_rate, dtype: float64
# Highest content type: Image
# Engagement rate: 0.06714727485974052
# Lowest content type: Text
# Engagement rate: 0.06602597774056249
# Percent difference: 1.6982665877118492

# %%
import matplotlib.pyplot as plt

platform_avg = df.groupby('platform')['engagement_rate'].mean()

plt.figure()
plt.bar(platform_avg.index, platform_avg.values,width=0.2)
plt.ylim(0.0650,0.0675)
plt.title("Average Engagement Rate by Platform")
plt.xlabel("Platform")
plt.ylabel("Average Engagement Rate")
plt.xticks(rotation=45)
plt.savefig("engagement rate vs platform")
plt.show()

# %%
platform_avg = df.groupby('platform')['engagement_rate'].mean()

highest_value = platform_avg.max()
highest_platform = platform_avg.idxmax()

print("Highest platform:", highest_platform)
print("Engagement rate:", highest_value)

lowest_value=platform_avg.min()
lowest_platform=platform_avg.idxmin()
print("lowest value",lowest_value)
print("engagement rate",lowest_platform)

percent_diff = (highest_value-lowest_value) / platform_avg.min() * 100
percent_diff
# Out:
# Highest platform: Facebook
# Engagement rate: 0.06687718476008647
# lowest value 0.06649974026837599
# engagement rate Twitter
# np.float64(0.5675879186703779)

# %%
df_twitter.describe()
# Out:
#        post_length          views         likes     comments       shares  \
# count  3347.000000    3347.000000   3347.000000  3347.000000  3347.000000
# mean     61.685390  100527.899313   5538.561398   691.666567   471.050194
# std      33.162092   57053.808000   4343.780714   619.257195   458.155935
# min       5.000000    2059.000000     35.000000     3.000000     2.000000
# 25%      34.000000   51672.500000   1989.000000   222.000000   135.000000
# 50%      62.000000  101108.000000   4518.000000   505.000000   321.000000
# 75%      90.000000  148952.000000   8139.500000   984.500000   668.500000
# max     119.000000  199999.000000  19786.000000  3675.000000  2679.000000
#
#        engagement_rate
# count      3347.000000
# mean          0.066500
# std           0.031654
# min           0.011227
# 25%           0.039979
# 50%           0.065561
# 75%           0.093856
# max           0.131419

# %%
df_instagram.describe()
# Out:
#        post_length          views         likes     comments       shares  \
# count  3354.000000    3354.000000   3354.000000  3354.000000  3354.000000
# mean     61.815742  153182.836911   8460.262075  1058.922481   727.656828
# std      33.446443   85346.756837   6579.487730   953.413681   692.862219
# min       5.000000    5290.000000     72.000000     5.000000     4.000000
# 25%      32.000000   79888.500000   3038.250000   343.250000   216.250000
# 50%      62.000000  154173.500000   6680.000000   770.500000   500.000000
# 75%      91.000000  226930.250000  12742.500000  1472.750000  1018.750000
# max     119.000000  299997.000000  29486.000000  5435.000000  3861.000000
#
#        engagement_rate
# count      3354.000000
# mean          0.066714
# std           0.031603
# min           0.011676
# 25%           0.039196
# 50%           0.067133
# 75%           0.093488
# max           0.132124

# %%
df_facebook.describe()
# Out:
#        post_length          views         likes     comments       shares  \
# count  3299.000000    3299.000000   3299.000000  3299.000000  3299.000000
# mean     63.597151  127698.512276   7098.941497   886.842680   607.899667
# std      33.159370   70813.927187   5486.055891   786.908137   590.025496
# min       5.000000    3132.000000     49.000000     6.000000     4.000000
# 25%      35.000000   68717.000000   2620.500000   291.000000   180.000000
# 50%      64.000000  127345.000000   5835.000000   651.000000   413.000000
# 75%      92.000000  189553.000000  10555.500000  1249.500000   865.000000
# max     119.000000  249923.000000  24843.000000  4638.000000  3464.000000
#
#        engagement_rate
# count      3299.000000
# mean          0.066877
# std           0.031545
# min           0.011679
# 25%           0.039807
# 50%           0.067411
# 75%           0.093689
# max           0.131649

# %%
df_facebook=df[df["platform"]=="Facebook"]
df_instagram=df[df["platform"]=="Instagram"]
df_twitter=df[df["platform"]=="Twitter"]
df_facebook.describe()
df_instagram.describe()
df_twitter.describe()

# %%
df.describe()
# Out:
#         post_length          views        likes      comments        shares  \
# count  10000.000000   10000.000000  10000.00000  10000.000000  10000.000000
# mean      62.359800  127151.950600   7033.26920    879.232800    602.262700
# std       33.264888   75169.927932   5673.59828    812.409438    597.573391
# min        5.000000    2059.000000     35.00000      3.000000      2.000000
# 25%       34.000000   65211.000000   2513.75000    275.000000    170.000000
# 50%       62.000000  122402.500000   5580.50000    635.000000    406.000000
# 75%       91.000000  184217.000000  10276.50000   1228.000000    837.000000
# max      119.000000  299997.000000  29486.00000   5435.000000   3861.000000
#
#        engagement_rate
# count     10000.000000
# mean          0.066696
# std           0.031598
# min           0.011227
# 25%           0.039637
# 50%           0.066719
# 75%           0.093694
# max           0.132124

# %%
df.head(10)
# Out:
#     platform post_type  post_length   views  likes  comments  shares  \
# 0   Facebook      Text           62   91660   2968       276     346
# 1  Instagram     Video          104  113115   4164       632     406
# 2   Facebook     Video           46   36043   3125       188     100
# 3   Facebook     Image           39  124886   5970       948     578
# 4  Instagram     Video           42   82831   8212      1104     334
# 5  Instagram     Video           71  221855   5252       459     775
# 6   Facebook      Text           45   69250   3580       530     192
# 7    Twitter     Video          103  171894  13050       917    1441
# 8   Facebook      Text           54  193496   2028       202     213
# 9   Facebook     Video          108   69345   1641       180     180
#
#    engagement_rate
# 0         0.039166
# 1         0.045989
# 2         0.094692
# 3         0.060023
# 4         0.116502
# 5         0.029235
# 6         0.062123
# 7         0.089637
# 8         0.012626
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   platform         10000 non-null  object
#  1   post_type        10000 non-null  object
#  2   post_length      10000 non-null  int64
#  3   views            10000 non-null  int64
#  4   likes            10000 non-null  int64
#  5   comments         10000 non-null  int64
#  6   shares           10000 non-null  int64
#  7   engagement_rate  10000 non-null  float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 625.1+ KB

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
df=pd.read_csv("C:\\Users\\Dell\\Desktop\\ibm project\\social_media_engagement_dataset.csv")
df.head()
# Out:
#     platform post_type  post_length   views  likes  comments  shares  \
# 0   Facebook      Text           62   91660   2968       276     346
# 1  Instagram     Video          104  113115   4164       632     406
# 2   Facebook     Video           46   36043   3125       188     100
# 3   Facebook     Image           39  124886   5970       948     578
# 4  Instagram     Video           42   82831   8212      1104     334
#
#    engagement_rate
# 0         0.039166
# 1         0.045989
# 2         0.094692
# 3         0.060023
# 4         0.116502
